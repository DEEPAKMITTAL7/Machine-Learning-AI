# %%
# importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Description: The data set contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer.
#
# Objective: Our objective is to classify the persons who are survived after the surgery and who are dead after the surgery from the given data set.
#
#
# There are 4 features.
#
# The age of person.
# Year in which patient has gone through the surgery.
# Nodes :- Lymph nodes are small, bean-shaped organs that act as filters along the lymph fluid channels.
# Status :- 1 = If the patients survives more than 5 years. 2 = Patients survive less than 5 years.

# %%
data = pd.read_csv("haberman.csv")
data
# Out:
#      age  year  nodes  status
# 0     30    64      1       1
# 1     30    62      3       1
# 2     30    65      0       1
# 3     31    59      2       1
# 4     31    65      4       1
# ..   ...   ...    ...     ...
# 300   74    63      0       1
# 301   75    62      1       1
# 302   76    67      0       1
# 303   77    65      3       1
# 304   78    65      1       2
#
# [305 rows x 4 columns]

# %%
data.isna().any()
# Out:
# age       False
# year      False
# nodes     False
# status    False
# dtype: bool

# %%
data['age'].describe()
# Out:
# count    305.000000
# mean      52.357377
# std       10.678010
# min       30.000000
# 25%       44.000000
# 50%       52.000000
# 75%       60.000000
# max       78.000000
# Name: age, dtype: float64

# %%
data['year'].describe()
# Out:
# count    305.000000
# mean      62.868852
# std        3.242783
# min       58.000000
# 25%       60.000000
# 50%       63.000000
# 75%       66.000000
# max       69.000000
# Name: year, dtype: float64

# %%
data['nodes'].describe()
# Out:
# count    305.000000
# mean       4.032787
# std        7.200528
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        4.000000
# max       52.000000
# Name: nodes, dtype: float64

# %%
# in nodes as per data, most values lies around 0-4 only but it got max value as 52, can be a outlier.

# %%
data['year'] = data['year']+1900
data
# Out:
#      age  year  nodes  status
# 0     30  1964      1       1
# 1     30  1962      3       1
# 2     30  1965      0       1
# 3     31  1959      2       1
# 4     31  1965      4       1
# ..   ...   ...    ...     ...
# 300   74  1963      0       1
# 301   75  1962      1       1
# 302   76  1967      0       1
# 303   77  1965      3       1
# 304   78  1965      1       2
#
# [305 rows x 4 columns]

# %%
data['year'].describe()
# Out:
# count     305.000000
# mean     1962.868852
# std         3.242783
# min      1958.000000
# 25%      1960.000000
# 50%      1963.000000
# 75%      1966.000000
# max      1969.000000
# Name: year, dtype: float64

# %%
data['status'].describe()
# Out:
# count    305.000000
# mean       1.262295
# std        0.440605
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        2.000000
# Name: status, dtype: float64

# %%
# this means most of the patients have survived more than 5 years

# %%
sns.set_style("whitegrid")
sns.FacetGrid(data, hue='status',height=4)\
    .map(plt.scatter, 'age', 'nodes')\
    .add_legend()

# %%
# can not make any conclusion here. need to get the pair plot now

# %%
sns.pairplot(data, hue = 'status')

# %% [raw]
# Got 9 graphs, lets analyse one by one.
#
# 1. people with age less than 50 died earlier.
# 2.
# 3. at nodes 0, maximum people lived longer
#
# 4.
# 5. after 1962 no one lived longer.
# 6.
#
# Not much help from this as well

# %%
data[data['nodes']==0]['status'].value_counts()
# Out:
# status
# 1    117
# 2     19
# Name: count, dtype: int64

# %%
sns.FacetGrid(data, hue="status", height=4).map(sns.distplot, "age").add_legend()
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()
# Out:
# c:\program files\python38\lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# c:\program files\python38\lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.FacetGrid(data, hue="status", height=4).map(sns.distplot, "year").add_legend()
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()
# Out:
# c:\program files\python38\lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# c:\program files\python38\lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.FacetGrid(data, hue="status", height=4).map(sns.distplot, "nodes").add_legend()
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()
# Out:
# c:\program files\python38\lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# c:\program files\python38\lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [raw]
# It's still nearly impossible to classify the survival status due to all of this overlapping.

# %%
haberman = data
haber_one = haberman[haberman['status'] == 1]
haber_two = haberman[haberman['status'] == 2]

label = ["pdf of status 1", "cdf of status 1", "pdf of status 2", "cdf of status 2"]

counts, bin_edges = np.histogram(haber_one["age"], bins=10, density = True)
pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)

plt.plot(bin_edges[1:], pdf)
plt.plot(bin_edges[1:], cdf)

counts, bin_edges = np.histogram(haber_two["age"], bins=10, density = True)
pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)

plt.plot(bin_edges[1:], pdf)
plt.plot(bin_edges[1:], cdf)

plt.title("pdf and cdf for Age")
plt.xlabel("Age")
plt.ylabel("% of person's")
plt.legend(label)

plt.show()

# %%
label = ["pdf of status 1","cdf of status 1","pdf of status 2","csf of status 2"]

counts, bin_edges = np.histogram(haber_one['year'], bins=10, density= True)
pdf = counts/sum(counts)
cdf = np.cumsum(pdf)

plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

counts, bin_edges = np.histogram(haber_two['year'], bins=10, density=True)
pdf = counts/sum(counts)
cdf = np.cumsum(pdf)

plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

plt.title('pdf and cdf for Year')
plt.xlabel('Year')
plt.ylabel("% of person's")
plt.legend(label)

# %%
label = ["pdf of status 1","cdf of status 1","pdf of status 2","csf of status 2"]

counts, bin_edges = np.histogram(haber_one['nodes'], bins=10, density = True)
pdf = counts/sum(counts)
cdf = np.cumsum(pdf)

plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

counts, bin_edges = np.histogram(haber_two['nodes'], bins=10, density=True)
pdf = counts/sum(counts)
cdf = np.cumsum(pdf)

plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

plt.title("pdf and cdf of Nodes")
plt.xlabel("Nodes")
plt.ylabel("% of person's ")
plt.legend(label)

# %% [markdown]
# There's so much overlapping in the CDF of year and we cannot classify there. It's almost on the same line till start to end.

# %%
sns.boxplot(x='status',y='age', data=haberman)
# Out:
# <Axes: xlabel='status', ylabel='age'>

# %%
sns.boxplot(x='status', y='year', data=haberman)
# Out:
# <Axes: xlabel='status', ylabel='year'>

# %%
sns.boxplot(x='status', y='nodes', data=haberman)
# Out:
# <Axes: xlabel='status', ylabel='nodes'>

# %%
sns.violinplot(x='status', y='age', data=haberman)
# Out:
# <Axes: xlabel='status', ylabel='age'>

# %%
sns.violinplot(x='status', y='nodes', data=haberman)
# Out:
# <Axes: xlabel='status', ylabel='nodes'>

# %%
sns.violinplot(x='status', y='year', data=haberman)
# Out:
# <Axes: xlabel='status', ylabel='year'>

# %%
sns.jointplot(x='age', y='year', data = haber_one, kind="kde")

# %%
sns.jointplot(x="nodes", y="year", data=haber_one, kind="kde")

# %%
sns.jointplot(x="age", y="nodes", data=haber_one, kind="kde")

# %% [markdown]
# # CONCLUSION
#
# The given dataset is imbalanced with too much overlapping and the features does not contain equal numbers.
# It's not linearly seperable so simple if-else condition won't work.
# The axillary_lymph_node is giving us tiny bit of useful information.
# We need to have a model which do not classifiy through if-else statements.
